# %%
import os
import re
import zipfile
import xml.dom.minidom

# %%
document = zipfile.ZipFile('C:/Users/USER/Desktop/test.docx')

# %%
document.namelist()
# name = 'word/document.xml'
# document.read('word/document.xml', pwd=None)
# Out:
# ['[Content_Types].xml',
#  '_rels/.rels',
#  'word/document.xml',
#  'word/_rels/document.xml.rels',
#  'word/theme/theme1.xml',
#  'word/settings.xml',
#  'word/numbering.xml',
#  'word/styles.xml',
#  'word/webSettings.xml',
#  'word/fontTable.xml',
#  'docProps/core.xml',
#  'docProps/app.xml']

# %%
uglyXml = xml.dom.minidom.parseString(document.read('word/document.xml')).toprettyxml(indent='  ')
text_re = re.compile('>\n\s+([^<>\s].*?)\n\s+</', re.DOTALL)    
prettyXml = text_re.sub('>\g<1></', uglyXml)

print(prettyXml)
# Out:
# <?xml version="1.0" ?>
# ...

# %%
# p = re.compile('<m:t>.</m:t>')
# formula = p.findall(prettyXml)
# print(formula)
